# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
import matplotlib.pyplot as plt
from collections import deque
import ale_py
import os

# %%
# !pip install autorom-accept-rom-license
# !pip install autorom
# print("stage1")
# !AutoROM
# print("stage2")
# !AutoROM --accept-license --skip-existing
# !pip install ale-py
# !pip install gymnasium[atari]
# !pip install autorom
# !AutoROM --accept-license

# %%
gym.register_envs(ale_py)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Neural Network Q-function Approximator

# %%
class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=256, n_layers=2):
        super(QNetwork, self).__init__()
        layers = []
        last_dim = input_dim
        # Create hidden layers
        for i in range(n_layers - 1):
            layers.append(nn.Linear(last_dim, hidden_dim))
            layers.append(nn.ReLU())
            last_dim = hidden_dim
        # Output layer
        layers.append(nn.Linear(last_dim, output_dim))
        self.model = nn.Sequential(*layers)

    def forward(self, x):
        return self.model(x)

# replay buffer
class ReplayBuffer:
    def __init__(self, capacity=1000000):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (np.array(states),
                np.array(actions),
                np.array(rewards),
                np.array(next_states),
                np.array(dones))

    def __len__(self):
        return len(self.buffer)

# epsilon greedy action selection
def epsilon_greedy_action(q_network, state, epsilon, n_actions):
    if random.random() < epsilon:
        return random.randrange(n_actions)
    else:
        state_tensor = torch.FloatTensor(np.array(state)).unsqueeze(0).to(device)

        with torch.no_grad():
            q_values = q_network(state_tensor)
        return q_values.argmax().item()

# %% [markdown]
# Compute expected q value for expexted sarsa

# %%
def compute_expected_q(q_network, next_state, epsilon, n_actions):
    next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0).to(device)
    with torch.no_grad():
        q_values = q_network(next_state_tensor).squeeze(0)
    # Determine the greedy action
    max_action = q_values.argmax().item()
    # Epsilon-greedy probabilities: probability for greedy action gets extra mass
    probs = np.ones(n_actions) * (epsilon / n_actions)
    probs[max_action] += (1 - epsilon)
    expected_q = (probs * q_values.cpu().numpy()).sum()
    return expected_q

# %% [markdown]
# Single-episode training function that can handle training w/ or w/o replay_buffer

# %%
def train_episode(env, q_network, optimizer, gamma, epsilon, algorithm="q_learning", max_steps=500, replay_buffer=None, batch_size=32):
    total_reward = 0.0
    state, _ = env.reset()
    done = False
    steps = 0  # Step counter

    while not done and steps < max_steps:
        steps += 1
        action = epsilon_greedy_action(q_network, state, epsilon, env.action_space.n)
        next_state, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        total_reward += reward

        # Update logic remains unchanged ...
        if replay_buffer is None:
            state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
            q_val = q_network(state_tensor)[0, action]  # Q-value of selected action
            if done:
                target = reward
            else:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0).to(device)
                with torch.no_grad():
                    q_next = q_network(next_state_tensor)  # Q-values for next state
                if algorithm == 'q_learning':
                    target = reward + gamma * q_next.max().item()
                elif algorithm == 'expected_sarsa':
                    n_actions = env.action_space.n
                    q_next = q_next.squeeze(0)
                    max_action = q_next.argmax().item()
                    probs = np.ones(n_actions) * (epsilon / n_actions)
                    probs[max_action] += (1 - epsilon)
                    expected_value = (probs * q_next.cpu().numpy()).sum()
                    target = reward + gamma * expected_value
                else:
                    raise ValueError("Unknown algorithm")
            target = torch.tensor(target).to(device)
            loss = (q_val - target) ** 2

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        else:
            replay_buffer.push(state, action, reward, next_state, done)
            if len(replay_buffer) >= batch_size:
                states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)
                states_tensor = torch.FloatTensor(states).to(device)
                actions_tensor = torch.LongTensor(actions).unsqueeze(1).to(device)
                rewards_tensor = torch.FloatTensor(rewards).to(device)
                next_states_tensor = torch.FloatTensor(next_states).to(device)
                dones_tensor = torch.FloatTensor(dones).to(device)

                q_values = q_network(states_tensor).gather(1, actions_tensor).squeeze(1)
                with torch.no_grad():
                    q_next = q_network(next_states_tensor)
                if algorithm == 'q_learning':
                    target_q = rewards_tensor + gamma * (1 - dones_tensor) * q_next.max(1)[0]
                elif algorithm == 'expected_sarsa':
                    n_actions = env.action_space.n
                    expected_qs = []
                    for i in range(batch_size):
                        q_vals = q_next[i]
                        max_action = q_vals.argmax().item()
                        probs = np.ones(n_actions) * (epsilon / n_actions)
                        probs[max_action] += (1 - epsilon)
                        expected_qs.append((probs * q_vals.cpu().numpy()).sum())
                    expected_qs = torch.FloatTensor(expected_qs).to(device)
                    target_q = rewards_tensor + gamma * (1 - dones_tensor) * expected_qs
                else:
                    raise ValueError("Unknown algorithm")
                loss = nn.MSELoss()(q_values, target_q)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

        state = next_state

    return total_reward

# %% [markdown]
# Code for a single run (an experiment on only one seed)

# %%
def run_experiment(env_name, algorithm, use_replay, epsilon, lr, seed=0, episodes=500, gamma=0.99, batch_size=32):

    env = gym.make(env_name)
    # Set maximum steps based on environment
    if env_name == 'Acrobot-v1':
        max_steps = 500
    elif env_name == "ALE/Assault-ram-v5":
        max_steps = 1000
    else:
        max_steps = 500  # default or other environments

    # Set seeds for reproducibility
    state, info = env.reset(seed=seed)
    env.action_space.seed(seed)
    env.observation_space.seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

    input_dim = env.observation_space.shape[0]
    output_dim = env.action_space.n

    q_network = QNetwork(input_dim, output_dim, hidden_dim=256, n_layers=2).to(device)
    optimizer = optim.Adam(q_network.parameters(), lr=lr)

    replay_buffer = ReplayBuffer(capacity=1000000) if use_replay else None
    episode_rewards = []
    for ep in range(episodes):
        total_reward = train_episode(env, q_network, optimizer, gamma, epsilon, algorithm, max_steps, replay_buffer, batch_size)
        episode_rewards.append(total_reward)

        print(f"Episode: {ep}, Env: {env_name}, Epsilon: {epsilon}, lr: {lr}, replay: {use_replay}, algo: {algorithm}, seed: {seed}  Total Reward: {total_reward}")
    print(f"Episode: {ep}, Mean Total Reward Per Episode: {np.mean(episode_rewards)}, ")
    env.close()
    return episode_rewards

# %% [markdown]
# Code for all experiments

# %%
import json
import numpy as np
import os

def run_multiple_trials(env_name, algorithm, use_replay, epsilon, lr, episodes=500, output_file="trials_assault.json"):
    all_rewards = []
    seeds = [0,1]
    trial_results = []

    # Load existing data if file exists
    if os.path.exists(output_file):
        with open(output_file, "r") as f:
            try:
                existing_data = json.load(f)
                if not isinstance(existing_data, list):
                    existing_data = []
            except json.JSONDecodeError:
                existing_data = []
    else:
        existing_data = []

    for seed in seeds:
        print(f"Seed {seed} ...")
        rewards = run_experiment(env_name, algorithm, use_replay, epsilon, lr, seed, episodes=episodes)
        all_rewards.append(rewards)

        trial_data = {
            "env_name": env_name,
            "replay": use_replay,
            "epsilon": epsilon,
            "lr": lr,
            "algo": algorithm,
            "seed": seed,
            "rewards": rewards
        }
        trial_results.append(trial_data)

    # Append new results to existing data
    existing_data.append(trial_results)

    # Save updated data to JSON file
    with open(output_file, "w") as f:
        json.dump(existing_data, f, indent=4)

    all_rewards = np.array(all_rewards)
    mean_rewards = np.mean(all_rewards, axis=0)
    std_rewards = np.std(all_rewards, axis=0)

    return mean_rewards, std_rewards

# %% [markdown]
# Testing

# %%
#  epsilon values
epsilon_list = [0.3]
# Step-size parameters
lr_list = [0.0001]
# Algorithms to compare
algorithms = ['q_learning', 'expected_sarsa']
# Whether to use replay buffer or not
replay_options = [True]

# num_seeds = 10      # 10 learning trials
episodes = 500     # 1000 episodes per run
gamma = 0.99        # Discount factor

#
# def exponential_moving_average(data, alpha=0.1):
#     smoothed = [data[0]]  # First value remains unchanged
#     for i in range(1, len(data)):
#         smoothed.append(alpha * data[i] + (1 - alpha) * smoothed[-1])
#     return np.array(smoothed)
#
episodes_range = np.arange(1, episodes + 1)
# alpha_ema = 0.5  # Smoothing factor for EMA

# %% [markdown]
# Run all experiments

# %% [markdown]
# # Plot for Assult

# %%
import gymnasium as gym
print(gym.envs.registry.keys())
# Out:
# dict_keys(['CartPole-v0', 'CartPole-v1', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Acrobot-v1', 'phys2d/CartPole-v0', 'phys2d/CartPole-v1', 'phys2d/Pendulum-v0', 'LunarLander-v3', 'LunarLanderContinuous-v3', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'CarRacing-v3', 'Blackjack-v1', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'CliffWalking-v0', 'Taxi-v3', 'tabular/Blackjack-v0', 'tabular/CliffWalking-v0', 'Reacher-v2', 'Reacher-v4', 'Reacher-v5', 'Pusher-v2', 'Pusher-v4', 'Pusher-v5', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'InvertedPendulum-v5', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedDoublePendulum-v5', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'HalfCheetah-v5', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Hopper-v5', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Swimmer-v5', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4', 'Walker2d-v5', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'Ant-v5', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'Humanoid-v5', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'HumanoidStandup-v5', 'GymV21Environment-v0', 'GymV26Environment-v0', 'Adventure-v0', 'AdventureDeterministic-v0', 'AdventureNoFrameskip-v0', 'Adventure-v4', 'AdventureDeterministic-v4', 'AdventureNoFrameskip-v4', 'Adventure-ram-v0', 'Adventure-ramDeterministic-v0', 'Adventure-ramNoFrameskip-v0', 'Adventure-ram-v4', 'Adventure-ramDeterministic-v4', 'Adventure-ramNoFrameskip-v4', 'AirRaid-v0', 'AirRaidDeterministic-v0', 'AirRaidNoFrameskip-v0', 'AirRaid-v4', 'AirRaidDeterministic-v4', 'AirRaidNoFrameskip-v4', 'AirRaid-ram-v0', 'AirRaid-ramDeterministic-v0', 'AirRaid-ramNoFrameskip-v0', 'AirRaid-ram-v4', 'AirRaid-ramDeterministic-v4', 'AirRaid-ramNoFrameskip-v4', 'Alien-v0', 'AlienDeterministic-v0', 'AlienNoFrameskip-v0', 'Alien-v4', 'AlienDeterministic-v4', 'AlienNoFrameskip-v4', 'Alien-ram-v0', 'Alien-ramDeterministic-v0', 'Alien-ramNoFrameskip-v0', 'Alien-ram-v4', 'Alien-ramDeterministic-v4', 'Alien-ramNoFrameskip-v4', 'Amidar-v0', 'AmidarDeterministic-v0', 'AmidarNoFrameskip-v0', 'Amidar-v4', 'AmidarDeterministic-v4', 'AmidarNoFrameskip-v4', 'Amidar-ram-v0', 'Amidar-ramDeterministic-v0', 'Amidar-ramNoFrameskip-v0', 'Amidar-ram-v4', 'Amidar-ramDeterministic-v4', 'Amidar-ramNoFrameskip-v4', 'Assault-v0', 'AssaultDeterministic-v0', 'AssaultNoFrameskip-v0', 'Assault-v4', 'AssaultDeterministic-v4', 'AssaultNoFrameskip-v4', 'Assault-ram-v0', 'Assault-ramDeterministic-v0', 'Assault-ramNoFrameskip-v0', 'Assault-ram-v4', 'Assault-ramDeterministic-v4', 'Assault-ramNoFrameskip-v4', 'Asterix-v0', 'AsterixDeterministic-v0', 'AsterixNoFrameskip-v0', 'Asterix-v4', 'AsterixDeterministic-v4', 'AsterixNoFrameskip-v4', 'Asterix-ram-v0', 'Asterix-ramDeterministic-v0', 'Asterix-ramNoFrameskip-v0', 'Asterix-ram-v4', 'Asterix-ramDeterministic-v4', 'Asterix-ramNoFrameskip-v4', 'Asteroids-v0', 'AsteroidsDeterministic-v0', 'AsteroidsNoFrameskip-v0', 'Asteroids-v4', 'AsteroidsDeterministic-v4', 'AsteroidsNoFrameskip-v4', 'Asteroids-ram-v0', 'Asteroids-ramDeterministic-v0', 'Asteroids-ramNoFrameskip-v0', 'Asteroids-ram-v4', 'Asteroids-ramDeterministic-v4', 'Asteroids-ramNoFrameskip-v4', 'Atlantis-v0', 'AtlantisDeterministic-v0', 'AtlantisNoFrameskip-v0', 'Atlantis-v4', 'AtlantisDeterministic-v4', 'AtlantisNoFrameskip-v4', 'Atlantis-ram-v0', 'Atlantis-ramDeterministic-v0', 'Atlantis-ramNoFrameskip-v0', 'Atlantis-ram-v4', 'Atlantis-ramDeterministic-v4', 'Atlantis-ramNoFrameskip-v4', 'BankHeist-v0', 'BankHeistDeterministic-v0', 'BankHeistNoFrameskip-v0', 'BankHeist-v4', 'BankHeistDeterministic-v4', 'BankHeistNoFrameskip-v4', 'BankHeist-ram-v0', 'BankHeist-ramDeterministic-v0', 'BankHeist-ramNoFrameskip-v0', 'BankHeist-ram-v4', 'BankHeist-ramDeterministic-v4', 'BankHeist-ramNoFrameskip-v4', 'BattleZone-v0', 'BattleZoneDeterministic-v0', 'BattleZoneNoFrameskip-v0', 'BattleZone-v4', 'BattleZoneDeterministic-v4', 'BattleZoneNoFrameskip-v4', 'BattleZone-ram-v0', 'BattleZone-ramDeterministic-v0', 'BattleZone-ramNoFrameskip-v0', 'Battl ...

# %%
os.makedirs("plots", exist_ok=True)

env_name = "ALE/Assault-ram-v5"

# Enable interactive mode so that plt.show() doesn't block each time
plt.ion()

# List to keep track of figure objects
figures = []

# Loop over every combination of replay, epsilon, and learning rate
for use_replay in replay_options:
    for epsilon in epsilon_list:
        for lr in lr_list:

            title = (f"ALE-Assault-ram-v5 - " +
                     f"{'Replay' if use_replay else 'No Replay'} - " +
                     f"ϵ: {epsilon}, LR: {lr}")

            # Build the filename for this combination
            plot_filename = f"plots/ALE-Assault-ram-v5_{'replay' if use_replay else 'no_replay'}_eps{epsilon}_lr{lr}.png"

            # Variables to hold the rewards for each algorithm
            q_mean_rewards, q_std_rewards = None, None
            e_sarsa_mean_rewards, e_sarsa_std_rewards = None, None

            # Run each algorithm for this combination
            for algo in algorithms:
                training_title = (f" ALE-Assault-ram-v5 - {algo.upper()} - " +
                                  f"{'Replay' if use_replay else 'No Replay'} - " +
                                  f"ϵ: {epsilon}, LR: {lr}")
                print("Running:", training_title)

                mean_rewards, std_rewards = run_multiple_trials(env_name, algo,
                                                                use_replay, epsilon,
                                                                lr, episodes, output_file="trials_assault_replay_0.3.json")

                if algo == "q_learning":
                    q_mean_rewards, q_std_rewards = mean_rewards, std_rewards
                else:
                    e_sarsa_mean_rewards, e_sarsa_std_rewards = mean_rewards, std_rewards

            # Create the plot for the current combination
            fig, ax = plt.subplots(figsize=(10, 6))
            ax.plot(episodes_range, q_mean_rewards, label="Q-Learning", color='green')
            ax.fill_between(episodes_range,
                            q_mean_rewards - q_std_rewards,
                            q_mean_rewards + q_std_rewards,
                            color='green', alpha=0.35)
            ax.plot(episodes_range, e_sarsa_mean_rewards, label="Expected SARSA", color='red')
            ax.fill_between(episodes_range,
                            e_sarsa_mean_rewards - e_sarsa_std_rewards,
                            e_sarsa_mean_rewards + e_sarsa_std_rewards,
                            color='red', alpha=0.35)

            ax.set_xlabel("Episode")
            ax.set_ylabel("Reward")
            ax.set_title(title)
            ax.legend()
            ax.grid(True)

            # Save the generated plot
            fig.savefig(plot_filename)
            print(f"Saved plot to {plot_filename}")
            figures.append(fig)

# Turn off interactive mode and display all the figures at once.
plt.ioff()
plt.show()
# Out:
# Running:  ALE-Assault-ram-v5 - Q_LEARNING - Replay - ϵ: 0.3, LR: 0.0001
# Seed 0 ...
# Episode: 0, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 1, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 2, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 3, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 4, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 5, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 6, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 7, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 8, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 9, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 462.0
# Episode: 10, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 11, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 12, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 13, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 14, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 15, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 16, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 17, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 18, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 19, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 20, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 21, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 22, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 23, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 24, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 25, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 26, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 27, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 28, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 29, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 30, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 31, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 32, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 33, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 34, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 35, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 36, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 37, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 38, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 39, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 40, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 41, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 42, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 43, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 44, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 45, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 46, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 47, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 48, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 49, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 50, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 51, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 52, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 525.0
# Episode: 53, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 54, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 55, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 56, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 57, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 58, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 59, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 60, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 61, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 62, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 63, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 64, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 65, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 66, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 67, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 68, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 69, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 70, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 71, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 72, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 73, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 74, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 75, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 76, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 77, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 78, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 79, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 525.0
# Episode: 80, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 81, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 82, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 83, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 84, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 85, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 86, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 87, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 88, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 89, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 90, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 91, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 92, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 93, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 94, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 95, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 96, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 97, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 98, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 99, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 100, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 101, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 102, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 103, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 104, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 105, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 106, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 107, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 108, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 109, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 110, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 111, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 112, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 113, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 114, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 115, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 116, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 117, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 147.0
# Episode: 118, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 119, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 120, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 121, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 122, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 123, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 124, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 125, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 126, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 127, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 128, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 129, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 130, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 131, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 132, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 462.0
# Episode: 133, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 134, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 135, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 136, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 137, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 138, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 139, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 140, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 141, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 142, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 143, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 144, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 145, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 146, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 147, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 148, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 149, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 150, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 151, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 152, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 153, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 154, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 155, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 156, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 157, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 483.0
# Episode: 158, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 462.0
# Episode: 159, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 160, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 161, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 162, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 163, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 164, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 165, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 166, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 167, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 168, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 169, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 170, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 171, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 172, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 173, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 174, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 175, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 176, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 177, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 178, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 179, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 180, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 181, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 182, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 183, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 184, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 185, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 186, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 187, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 188, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 189, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 190, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 191, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 192, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 193, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 194, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 195, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 196, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 197, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 198, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 483.0
# Episode: 199, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 200, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 201, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 202, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 203, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 204, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 205, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 206, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 207, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 208, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 209, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 210, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 211, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 212, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 213, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 214, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 483.0
# Episode: 215, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 216, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 217, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 218, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 219, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 220, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 221, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 222, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 223, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 224, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 225, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 226, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 227, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 228, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 229, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 230, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 231, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 232, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 233, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 234, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 235, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 462.0
# Episode: 236, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 237, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 238, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 239, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 240, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 241, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 242, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 243, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 244, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 245, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 246, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 247, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 248, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 249, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 250, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 251, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 252, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 253, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 254, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 255, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 256, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 257, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 258, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 259, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 260, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 261, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 262, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 263, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 264, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 265, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 266, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 267, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 268, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 269, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 270, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 271, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 272, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 273, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 274, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 275, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 276, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 277, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 278, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 279, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 280, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 281, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 282, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 283, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 284, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 285, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 286, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 287, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 288, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 289, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 290, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 291, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 462.0
# Episode: 292, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 293, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 294, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 295, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 296, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 297, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 298, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 299, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 300, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 126.0
# Episode: 301, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 302, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 303, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 304, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 305, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 306, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 307, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 308, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 309, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 310, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 311, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 312, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 313, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 314, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 315, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 316, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 317, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 318, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 319, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 320, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 321, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 322, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 323, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 324, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 231.0
# Episode: 325, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 326, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 327, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 328, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 483.0
# Episode: 329, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 294.0
# Episode: 330, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 331, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 332, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 333, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 334, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 335, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 336, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 337, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 338, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 168.0
# Episode: 339, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 340, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 341, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 342, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 343, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 344, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 345, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 346, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 546.0
# Episode: 347, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 399.0
# Episode: 348, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 349, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 350, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 351, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 352, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 441.0
# Episode: 353, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 483.0
# Episode: 354, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 355, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 356, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 357, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 609.0
# Episode: 358, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 359, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 360, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 361, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 362, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 363, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 420.0
# Episode: 364, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 210.0
# Episode: 365, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 315.0
# Episode: 366, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 367, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 368, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 369, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 370, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 371, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 372, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 373, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 336.0
# Episode: 374, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 378.0
# Episode: 375, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 252.0
# Episode: 376, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 377, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 189.0
# Episode: 378, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 273.0
# Episode: 379, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 357.0
# Episode: 380, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: q_learning, seed: 0  Total Reward: 504.0
# ...
# Episode: 378, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 379, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 380, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 381, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 382, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 252.0
# Episode: 383, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 384, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 385, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 386, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 231.0
# Episode: 387, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 388, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 389, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 420.0
# Episode: 390, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 391, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 483.0
# Episode: 392, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 393, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 394, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 395, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 396, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 397, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 398, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 231.0
# Episode: 399, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 400, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 504.0
# Episode: 401, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 252.0
# Episode: 402, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 403, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 404, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 405, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 406, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 407, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 408, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 409, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 410, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 411, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 412, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 420.0
# Episode: 413, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 414, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 415, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 416, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 417, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 418, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 419, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 420, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 421, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 84.0
# Episode: 422, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 423, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 424, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 425, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 426, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 420.0
# Episode: 427, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 428, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 429, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 430, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 431, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 432, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 567.0
# Episode: 433, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 434, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 252.0
# Episode: 435, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 420.0
# Episode: 436, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 437, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 420.0
# Episode: 438, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 210.0
# Episode: 439, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 440, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 252.0
# Episode: 441, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 442, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 443, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 444, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 445, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 446, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 447, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 448, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 449, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 450, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 420.0
# Episode: 451, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 452, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 453, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 454, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 455, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 456, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 457, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 458, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 459, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 460, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 461, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 462, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 252.0
# Episode: 463, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 464, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 462.0
# Episode: 465, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 630.0
# Episode: 466, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 467, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 252.0
# Episode: 468, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 469, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 470, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 471, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 472, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 473, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 231.0
# Episode: 474, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 210.0
# Episode: 475, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 483.0
# Episode: 476, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 210.0
# Episode: 477, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 478, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 479, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 480, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 481, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 482, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 483, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 484, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 485, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 315.0
# Episode: 486, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 504.0
# Episode: 487, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 273.0
# Episode: 488, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 189.0
# Episode: 489, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 490, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 491, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 525.0
# Episode: 492, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 336.0
# Episode: 493, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 231.0
# Episode: 494, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 378.0
# Episode: 495, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 399.0
# Episode: 496, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 497, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 294.0
# Episode: 498, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 357.0
# Episode: 499, Env: ALE/Assault-ram-v5, Epsilon: 0.3, lr: 0.0001, replay: True, algo: expected_sarsa, seed: 1  Total Reward: 441.0
# Episode: 499, Mean Total Reward Per Episode: 324.156,
# Saved plot to plots/ALE-Assault-ram-v5_replay_eps0.3_lr0.0001.png
